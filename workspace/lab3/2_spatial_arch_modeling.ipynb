# %% [markdown]
# ## Part 2: Spatial Architecture Modeling
# Now that you are familiar with the basic single PE setup, let’s look at an example of a full system as shown in the figure below. This design is composed of two levels of on-chip storage -- the global buffer and the local scratchpads in each PE as described in part 1. Each datatype is sent via a network from the global buffer to the PE array, and there are inter-PE networks that are capable of sending various data types within the array. We provide you with the loop nest of a matmul on this design in the figure below.
#
# <br>
# <div class="row">
#   <div class="column">
#     <img align="left" src="designs/system/figures/arch.png" alt="Full System  Architecture Diagram" style="margin:50px 0px 0px 50px; width:40%">
#   </div>
#   <div class="column">
#     <img  align="left"  src="designs/system/figures/loopnest.png" alt="System Loopnest" style="width:50%">
#   </div>
# </div>

# %% [markdown]
# ### Question 1
# You are provided with a PE array that has 16 PEs. Assume you can design different architectures and associated mappings for every layer shape (i.e. both ```architecture.yaml``` and ```mapping.yaml``` can change across layer shapes).
#
# In specific, you can select the height and width of the PE array as long as the total number of PEs equal to 16, while keeping other architectural attributes the same.

# %%
import pandas as pd
import numpy as np
from loaders import *

show_config('designs/system/arch.yaml')
# Out:
# # ========================================================================
# # Please do not modify this file. If there are double-curly-brace-enclosed
# # statements, they are placeholders that should be set from the notebooks.
# # ========================================================================
# architecture:
#   version: 0.4
#   nodes:
#   - !Container
#     name: system_arch
#     attributes:
#       # Top-level attributes inherited by all components unless overridden
#       technology: "45nm"
#       global_cycle_seconds: 1e-9
#       datawidth: 16
#
#   - !Component
#     name: DRAM                 # offchip DRAM is the source of all datatypes
#     class: DRAM                # assume DRAM is large enough to store all the data, so no depth specification needed
#     attributes:
#       width: 64                # width in bits
#       datawidth: datawidth
#
#   - !Container
#     name: chip
#
#   - !Component
#     name: global_buffer
#     class: SRAM
#     attributes:
#       width: 128
#       depth: 2048
#       datawidth: datawidth
#       n_banks: 1
#       n_rdwr_ports: 2
#
#   - !Container
#     name: PE
#     spatial: {meshX: {{pe_meshX}}, meshY: {{pe_meshY}}}
#
#   - !Component
#     name: scratchpad
#     class: smart_storage  # definitions of the compound classes can be found under "components" folder
#     attributes: {depth: 128, width: 16, datawidth: datawidth}
#
#   # registers for the mac unit
#   - !Component
#     name: weight_reg
#     class: reg_storage
#     attributes: {depth: 1, width: 16, datawidth: datawidth}
#
#   - !Component
#     name: input_activation_reg
#     class: reg_storage
#     attributes: {depth: 1, width: 16, datawidth: datawidth}
#
#   - !Component
#     name: output_activation_reg
#     class: reg_storage
#     attributes: {depth: 1, width: 16, datawidth: datawidth}
#
#   - !Component
#     name: mac
#     class: mac_compute
#     attributes: {num_pipline_stages: 2, datawidth: datawidth}

# %%
answer(
    question='2.1',
    subquestion='What variable names change the number of PEs in the X and Y dimensions? Please give the name of the double-curly-brace-enclosed variables. Case sensitive.',
    answer= ['pe_meshX', 'pe_meshY'], # [First variable in curly braces, second variable in curly braces]
    required_type=[str, str]
)
# Out:
# 2.1: What variable names change the number of PEs in the X and Y dimensions? Please give the name of the double-curly-brace-enclosed variables. Case sensitive.
# 	['pe_meshX', 'pe_meshY']

# %% [markdown]
# ## Question 2
#
# With this spatial architecture, we will explore how the PE array shape impacts two metrics: utilization, which impacts throughput, and spatial data reuse, which impacts energy.
#
# We start with the workload and mapping below. The mapping has placeholder variables in double curly brackets that we will replace with numeric values later.

# %%
show_config('layer_shapes/conv2.yaml')
# Out:
# problem:
#   version: 0.4
#   shape:
#     name: "CNN_Layer"
#     dimensions: [ C, M, R, S, N, P, Q ]
#     coefficients:
#     - name: Wstride
#       default: 1
#     - name: Hstride
#       default: 1
#     - name: Wdilation
#       default: 1
#     - name: Hdilation
#       default: 1
#
#     data_spaces:
#     - name: Weights
#       projection:
#       - [ [C] ]
#       - [ [M] ]
#       - [ [R] ]
#       - [ [S] ]
#     - name: Inputs
#       projection:
#       - [ [N] ]
#       - [ [C] ]
#       - [ [R, Wdilation], [P, Wstride] ] # SOP form: R*Wdilation + P*Wstride
#       - [ [S, Hdilation], [Q, Hstride] ] # SOP form: S*Hdilation + Q*Hstride
#     - name: Outputs
#       projection:
#       - [ [N] ]
#       - [ [M] ]
#       - [ [Q] ]
#       - [ [P] ]
#       read_write: True
#
#   instance:
#     C: 4  # inchn
#     M: 8  # outchn
#     R: 5   # filter height
#     S: 5   # filter width
#     P: 28  # ofmap height
#     Q: 28  # ofmap width
#     N: 50   # batch size

# %%
show_config('designs/system/map.yaml')
# Out:
# # ========================================================================
# # Please do not modify this file. If there are double-curly-brace-enclosed
# # statements, they are placeholders that should be set from the notebooks.
# # ========================================================================
# mapping:
# - target: DRAM
#   type: temporal
#   factors:
#   - P=1
#   - Q=1
#   - R=1
#   - S=1
#   - N={{DRAM_factor_N}}
#   - M={{DRAM_factor_M}}
#   - C={{DRAM_factor_C}}
#   permutation: [S, R, Q, P, C, M, N] # don't change this
#
# - target: global_buffer
#   type: temporal
#   factors:
#   - P=1
#   - Q=1
#   - R=1
#   - S=1
#   - N={{global_buffer_factor_N}}
#   - M={{global_buffer_factor_M}}
#   - C={{global_buffer_factor_C}}
#   permutation: [S, R, Q, P, C, M, N] # don't change this
#
# - target: PE
#   type: spatial  # spatial constraint specification
#   factors:
#   - P=1
#   - Q=1
#   - R=1
#   - S=1
#   - N=1
#   - M={{PE_spatial_factor_M}}
#   - C={{PE_spatial_factor_C}}
#   permutation: [C, M, R, S, P, Q, N]
#   # tells at which index should the dimensions be mapped to Y (PE cols),
#   # the dimensions before that index all should map to X (PE rows)
#   split: 1
#
# - target: scratchpad
#   type: temporal
#   factors:
#   - R=0
#   - S=0
#   - P=0
#   - Q=0
#   - M=1
#   - C=1
#   - N={{scratchpad_factor_N}}
#   permutation: [Q, P, N, C, M, S, R]
#
# - target: scratchpad
#   type: dataspace
#   keep: [Weights]
#   bypass: [Inputs, Outputs]
#
# - target: weight_reg
#   type: dataspace
#   keep: [Weights]
#   bypass: [Inputs, Outputs]
# - target: weight_reg
#   type: temporal
#   factors: [R=1, S=1, P=1, Q=1, N=1, C=1, M=1]
#   permutation: [R, S, P, Q, C, M, N]
# - target: input_activation_reg
#   type: dataspace
#   keep: [Inputs]
#   bypass: [Weights, Outputs]
# - target: input_activation_reg
#   type: temporal
#   factors: [R=1, S=1, P=1, Q=1, N=1, C=1, M=1]
#   permutation: [R, S, P, Q, C, M, N]
# - target: output_activation_reg
#   type: dataspace
#   keep: [Outputs]
#   bypass: [Weights, Inputs]
# - target: output_activation_reg
#   type: temporal
#   factors: [R=1, S=1, P=1, Q=1, N=1, C=1, M=1]
#   permutation: [R, S, P, Q, C, M, N]

# %%
answer(
    question='2.2',
    subquestion=f'Which rank (e.g., C, M, or P) is mapped to the X dimension of the PE array? Case sensitive.',
    answer= 'C',
    required_type=('C', 'M', 'N', 'R', 'S', 'P', 'Q')
)
answer(
    question='2.2',
    subquestion=f'Which rank (e.g., C, M, or P) is mapped to the Y dimension of the PE array? Case sensitive.',
    answer= 'M',
    required_type=('C', 'M', 'N', 'R', 'S', 'P', 'Q')
)
# Out:
# 2.2: Which rank (e.g., C, M, or P) is mapped to the X dimension of the PE array? Case sensitive.
# 	C
# 2.2: Which rank (e.g., C, M, or P) is mapped to the Y dimension of the PE array? Case sensitive.
# 	M

# %% [markdown]
# **For the rest of Part 2 (to the end of this notebook), we will assume a 1x16 PE array (the array shape is 1 in the X-dimension and 16 in the Y-dimension).**

# %%
ARCH_CONFIG = {'pe_meshX': 1, 'pe_meshY': 16}

# %% [markdown]
# ### Question 3
#
# We will look at the impact of PE utilization on latency, and how PE utilization depends on the mapping. Inspect the following mapping.

# %%
config_example = dict( # Do not change this configuration!
    DRAM_factor_N=50,
    DRAM_factor_M=2,
    DRAM_factor_C=4,
    global_buffer_factor_N=1,
    global_buffer_factor_M=4,
    global_buffer_factor_C=1,
    PE_spatial_factor_M=1,
    PE_spatial_factor_C=1,
    scratchpad_factor_N=1,
)

full_config = {
    **config_example,
    **ARCH_CONFIG
}

result = run_timeloop_model(
    full_config,
    architecture='designs/system/arch.yaml',
    mapping='designs/system/map.yaml',
    problem='layer_shapes/conv2.yaml'
)
stats = open('./output_dir/timeloop-model.stats.txt', 'r').read()
mapping = result.mapping
one_pe_latency = result.cycles
print(mapping)
# Out:
# [INFO] 2025-03-03 22:33:59,035 - pytimeloop.accelergy_interface - Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# INFO:pytimeloop.accelergy_interface:Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# DRAM [ Weights:800 (800) Inputs:204800 (204800) Outputs:313600 (313600) ]
# -------------------------------------------------------------------------
# | for N in [0:50)
# |   for M in [0:2)
# |     for C in [0:4)
#
# global_buffer [ Weights:100 (100) Inputs:1024 (1024) Outputs:3136 (3136) ]
# --------------------------------------------------------------------------
# |       for M in [0:4)
#
# inter_PE_spatial [ ]
# scratchpad [ Weights:25 (25) ]
# ------------------------------
# |         for R in [0:5)
# |           for S in [0:5)
# |             for P in [0:28)
# |               for Q in [0:28)
#
# weight_reg [ Weights:1 (1) ]
# input_activation_reg [ Inputs:1 (1) ]
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 << Compute >>

# %%
answer(
    question='2.3',
    subquestion=f'What is the PE utilization (number of utilized PEs divided by total number of PEs)?.',
    answer= 1/16,
    required_type=Number
)
# Out:
# 2.3: What is the PE utilization (number of utilized PEs divided by total number of PEs)?.
# 	0.0625

# %% [markdown]
# As a result of this utilization, the mapping achieves the following latency.

# %%
one_pe_latency
# Out:
# 31360000

# %% [markdown]
# In the following mapping, we map more of the M rank to the PE array.

# %%
config_example = dict( # Do not change this configuration!
    DRAM_factor_N=50,
    DRAM_factor_M=2,
    DRAM_factor_C=4,
    global_buffer_factor_N=1,
    global_buffer_factor_M=1,
    global_buffer_factor_C=1,
    PE_spatial_factor_M=4,
    PE_spatial_factor_C=1,
    scratchpad_factor_N=1,
)

full_config = {
    **config_example,
    **ARCH_CONFIG
}

result = run_timeloop_model(
    full_config,
    architecture='designs/system/arch.yaml',
    mapping='designs/system/map.yaml',
    problem='layer_shapes/conv2.yaml'
)
stats = open('./output_dir/timeloop-model.stats.txt', 'r').read()
mapping = result.mapping
four_pe_latency = result.cycles
print(mapping)
# Out:
# [INFO] 2025-03-03 22:34:00,541 - pytimeloop.accelergy_interface - Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# INFO:pytimeloop.accelergy_interface:Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# DRAM [ Weights:800 (800) Inputs:204800 (204800) Outputs:313600 (313600) ]
# -------------------------------------------------------------------------
# | for N in [0:50)
# |   for M in [0:2)
# |     for C in [0:4)
#
# global_buffer [ Weights:100 (100) Inputs:1024 (1024) Outputs:3136 (3136) ]
# inter_PE_spatial [ ]
# --------------------
# |       for M in [0:4) (Spatial-Y)
#
# scratchpad [ Weights:25 (25) ]
# ------------------------------
# |         for R in [0:5)
# |           for S in [0:5)
# |             for P in [0:28)
# |               for Q in [0:28)
#
# weight_reg [ Weights:1 (1) ]
# input_activation_reg [ Inputs:1 (1) ]
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 << Compute >>

# %%
answer(
    question='2.3',
    subquestion=f'What is the PE utilization (number of utilized PEs divided by total number of PEs)?.',
    answer= 4/16,
    required_type=Number
)
# Out:
# 2.3: What is the PE utilization (number of utilized PEs divided by total number of PEs)?.
# 	0.25

# %%
four_pe_latency
# Out:
# 7840000

# %%
print(f'As expected, this latency is {one_pe_latency/four_pe_latency} times lower.')
# Out:
# As expected, this latency is 4.0 times lower.

# %% [markdown]
# However, note that simply increasing the factor of the spatially mapped rank is not always possible.

# %%
answer(
    question='2.3',
    subquestion=f'What is the maximum factor of the spatially mapped C rank based on the PE array shape?',
    answer= 1,
    required_type=int
)
# Out:
# 2.3: What is the maximum factor of the spatially mapped C rank based on the PE array shape?
# 	1

# %% [markdown]
# Moreover, even if we can increase the factor of the spatially mapped rank, it does not always result in higher utilization.

# %%
answer(
    question='2.3',
    subquestion=f'Assuming a larger factor of the spatial loop is possible given the PE array shape, increasing the factor will not increase PE utilization if the workload were _____-bound.',
    answer= 'memory bandwidth',
    required_type=('computation', 'memory bandwidth')
)
# Out:
# 2.3: Assuming a larger factor of the spatial loop is possible given the PE array shape, increasing the factor will not increase PE utilization if the workload were _____-bound.
# 	memory bandwidth

# %% [markdown]
# ### Question 4
#
# Now, we look at how spatial mapping affects spatial data reuse. Again, we use the mappings from before.

# %%
config_example = dict( # Do not change this configuration!
    DRAM_factor_N=50,
    DRAM_factor_M=2,
    DRAM_factor_C=4,
    global_buffer_factor_N=1,
    global_buffer_factor_M=4,
    global_buffer_factor_C=1,
    PE_spatial_factor_M=1,
    PE_spatial_factor_C=1,
    scratchpad_factor_N=1,
)

full_config = {
    **config_example,
    **ARCH_CONFIG
}

result = run_timeloop_model(
    full_config,
    architecture='designs/system/arch.yaml',
    mapping='designs/system/map.yaml',
    problem='layer_shapes/conv2.yaml'
)
stats = open('./output_dir/timeloop-model.stats.txt', 'r').read()
mapping = result.mapping
print(mapping)
print(stats)
# Out:
# [INFO] 2025-03-03 22:34:02,156 - pytimeloop.accelergy_interface - Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# INFO:pytimeloop.accelergy_interface:Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# DRAM [ Weights:800 (800) Inputs:204800 (204800) Outputs:313600 (313600) ]
# -------------------------------------------------------------------------
# | for N in [0:50)
# |   for M in [0:2)
# |     for C in [0:4)
#
# global_buffer [ Weights:100 (100) Inputs:1024 (1024) Outputs:3136 (3136) ]
# --------------------------------------------------------------------------
# |       for M in [0:4)
#
# inter_PE_spatial [ ]
# scratchpad [ Weights:25 (25) ]
# ------------------------------
# |         for R in [0:5)
# |           for S in [0:5)
# |             for P in [0:28)
# |               for Q in [0:28)
#
# weight_reg [ Weights:1 (1) ]
# input_activation_reg [ Inputs:1 (1) ]
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 << Compute >>
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16 (1*16)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 1
#     Computes (total)        : 31360000
#     Cycles                  : 31360000
#     Energy (total)          : 102704000.00 pJ
#     Area (total)            : 27624.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 313600
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31046400
#         Scalar fills (per-instance)              : 31046400
#         Scalar updates (per-instance)            : 31360000
#         Temporal reductions (per-instance)       : 31046400
#         Address generations (per-cluster)        : 62406400
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 13457203.20 pJ
#         Energy (total)                           : 13457203.20 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.98 words/cycle
#         Shared Bandwidth (total)                 : 2.98 words/cycle
#         Read Bandwidth (per-instance)            : 0.99 words/cycle
#         Read Bandwidth (total)                   : 0.99 words/cycle
#         Write Bandwidth (per-instance)           : 1.99 words/cycle
#         Write Bandwidth (total)                  : 1.99 words/cycle
#
# Level 2
# -------
# === input_activation_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31360000
#         Scalar fills (per-instance)              : 31360000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 62720000
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 9031680.00 pJ
#         Energy (total)                           : 9031680.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 2.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 1.00 words/cycle
#
# Level 3
# -------
# === weight_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31360000
#         Scalar fills (per-instance)              : 40000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 31400000
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 4521600.00 pJ
#         Energy (total)                           : 4521600.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 1.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 4
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 128
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 128
#         Min utilization                 : 0.00
#         Vector access energy            : 0.83 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 24235.01 pJ
#         Area                            : 1965.98 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 25
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 40000
#         Scalar fills (per-instance)              : 40000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 80000
#         Energy (per-scalar-access)               : 0.83 pJ
#         Energy (per-instance)                    : 66732.80 pJ
#         Energy (total)                           : 66732.80 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.00 words/cycle
#         Shared Bandwidth (total)                 : 0.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 6
# -------
# === global_buffer ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 16384
#         Word bits                       : 16
#         Block size                      : 8
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 16384
#         Min utilization                 : 0.00
#         Vector access energy            : 27.53 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 29074.08 pJ
#         Area                            : 97538.70 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 100
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 40000
#         Scalar fills (per-instance)              : 40000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 80000
#         Energy (per-scalar-access)               : 2.99 pJ
#         Energy (per-instance)                    : 239174.00 pJ
#         Energy (total)                           : 239174.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.00 words/cycle
#         Shared Bandwidth (total)                 : 0.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 1024
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31360000
#         Scalar fills (per-instance)              : 409600
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 31769600
#         Energy (per-scalar-access)               : 2.55 pJ
#         Energy (per-instance)                    : 81014410.88 pJ
#         Energy (total)                           : 81014410.88 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.01 words/cycle
#         Shared Bandwidth (total)                 : 1.01 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.01 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#     Outputs:
#         Partition size                           : 313600
#         Utilized capacity                        : 3136
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31046400
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 31360000
#         Temporal reductions (per-instance)       : 31046400
#         Address generations (per-cluster)        : 31360000
#         Energy (per-scalar-access)               : 2.99 pJ
#         Energy (per-instance)                    : 186716365.92 pJ
#         Energy (total)                           : 186716365.92 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.99 words/cycle
#         Shared Bandwidth (total)                 : 1.99 words/cycle
#         Read Bandwidth (per-instance)            : 0.99 words/cycle
#         Read Bandwidth (total)                   : 0.99 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 1.00 words/cycle
#
# Level 7
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                      : DRAM
#         Size                            : -
#         Word bits                       : 16
#         Block size                      : 4
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : -
#         Min utilization                 : 0.00
#         Vector access energy            : 512.00 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 0.00 pJ
#         Area                            : 0.00 um^2
#
#     STATS
#     -----
#     Cycles               : 31360000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 800
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 40000
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 40000
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 5120000.00 pJ
#         Energy (total)                           : 5120000.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.00 words/cycle
#         Shared Bandwidth (total)                 : 0.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 204800
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 409600
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 409600
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 52428800.00 pJ
#         Energy (total)                           : 52428800.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.01 words/cycle
#         Read Bandwidth (total)                   : 0.01 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 313600
#         Utilized capacity                        : 313600
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 313600
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 313600
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 40140800.00 pJ
#         Energy (total)                           : 40140800.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.01 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#
# Networks
# --------
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 31360000
#     Total reduction ops                     : 31046400
#     Total ops                               : 62406400
#     Total memory accesses required          : 519200
#     Optimal Op per Byte                     : 60.10
#
# === output_activation_reg ===
#     Total scalar accesses                   : 93452800
#     Op per Byte                             : 0.33
# === input_activation_reg ===
#     Total scalar accesses                   : 62720000
#     Op per Byte                             : 0.50
# === weight_reg ===
#     Total scalar accesses                   : 31400000
#     Op per Byte                             : 0.99
# === scratchpad ===
#     Total scalar accesses                   : 80000
#     Op per Byte                             : 390.04
# === inter_PE_spatial ===
# === global_buffer ===
#     Total scalar accesses                   : 94256000
#     Op per Byte                             : 0.33
# === DRAM ===
#     Total scalar accesses                   : 763200
#     Op per Byte                             : 40.88
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1.99
# Utilization: 6.25%
# Cycles: 31360000
# Energy: 495.60 uJ
# EDP(J*cycle): 1.55e+04
# Area: 0.00 mm^2
#
# Computes = 31360000
# fJ/Compute
#     mac                                             = 3275.00
#     output_activation_reg                           = 430.24
#     input_activation_reg                            = 289.12
#     weight_reg                                      = 145.30
#     scratchpad                                      = 2.90
#     global_buffer                                   = 8545.89
#     DRAM                                            = 3115.10
#     Total                                           = 15803.55

# %% [markdown]
# We now will find the number of reads from the `global_buffer` for the above mapping by tensor by looking through the outputted stats file.

# %%
# Answer by setting these variables
one_pe_input_reads = 31360000 # YOUR ANSWER HERE
one_pe_weight_reads = 40000 # YOUR ANSWER HERE
one_pe_output_reads = 31046400 # YOUR ANSWER HERE
########################
#### YOUR CODE HERE ####
########################
answer(
    question='2.4',
    subquestion=f'How many input reads does each utilized PE fetch from the global_buffer?',
    answer=one_pe_input_reads,
    required_type=Number
)
answer(
    question='2.4',
    subquestion=f'How many weight reads does each utilized PE fetch from the global_buffer?',
    answer=one_pe_weight_reads,
    required_type=Number
)
answer(
    question='2.4',
	subquestion=f'How many output reads does each utilized PE fetch from the global_buffer?',
	answer=one_pe_output_reads,
	required_type=Number
)

manual_one_pe_global_buffer_reads = one_pe_input_reads + one_pe_weight_reads + one_pe_output_reads
print('If you answered correctly, the following equality should hold.')
print(f'Is {manual_one_pe_global_buffer_reads} == {62446400.0}? {manual_one_pe_global_buffer_reads == 62446400.0}.')
# Out:
# 2.4: How many input reads does each utilized PE fetch from the global_buffer?
# 	31360000
# 2.4: How many weight reads does each utilized PE fetch from the global_buffer?
# 	40000
# 2.4: How many output reads does each utilized PE fetch from the global_buffer?
# 	31046400
# If you answered correctly, the following equality should hold.
# Is 62446400 == 62446400.0? True.

# %% [markdown]
# As before, we increase the factor of M that is spatially mapped.

# %%
config_example = dict( # Do not change this configuration!
    DRAM_factor_N=50,
    DRAM_factor_M=2,
    DRAM_factor_C=4,
    global_buffer_factor_N=1,
    global_buffer_factor_M=1,
    global_buffer_factor_C=1,
    PE_spatial_factor_M=4,
    PE_spatial_factor_C=1,
    scratchpad_factor_N=1,
)

full_config = {
    **config_example,
    **ARCH_CONFIG
}

result = run_timeloop_model(
    full_config,
    architecture='designs/system/arch.yaml',
    mapping='designs/system/map.yaml',
    problem='layer_shapes/conv2.yaml'
)
stats = open('./output_dir/timeloop-model.stats.txt', 'r').read()
mapping = result.mapping
print(mapping)
print(stats)
# Out:
# [INFO] 2025-03-03 22:34:03,666 - pytimeloop.accelergy_interface - Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# INFO:pytimeloop.accelergy_interface:Running Accelergy with command: accelergy /home/workspace/lab3/output_dir/parsed-processed-input.yaml -o ./output_dir/ -v
# DRAM [ Weights:800 (800) Inputs:204800 (204800) Outputs:313600 (313600) ]
# -------------------------------------------------------------------------
# | for N in [0:50)
# |   for M in [0:2)
# |     for C in [0:4)
#
# global_buffer [ Weights:100 (100) Inputs:1024 (1024) Outputs:3136 (3136) ]
# inter_PE_spatial [ ]
# --------------------
# |       for M in [0:4) (Spatial-Y)
#
# scratchpad [ Weights:25 (25) ]
# ------------------------------
# |         for R in [0:5)
# |           for S in [0:5)
# |             for P in [0:28)
# |               for Q in [0:28)
#
# weight_reg [ Weights:1 (1) ]
# input_activation_reg [ Inputs:1 (1) ]
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 << Compute >>
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16 (1*16)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 4
#     Computes (total)        : 31360000
#     Cycles                  : 7840000
#     Energy (total)          : 102704000.00 pJ
#     Area (total)            : 27624.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 78400
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 4
#         Utilized clusters (max)                  : 4
#         Scalar reads (per-instance)              : 7761600
#         Scalar fills (per-instance)              : 7761600
#         Scalar updates (per-instance)            : 7840000
#         Temporal reductions (per-instance)       : 7761600
#         Address generations (per-cluster)        : 15601600
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 3364300.80 pJ
#         Energy (total)                           : 13457203.20 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.98 words/cycle
#         Shared Bandwidth (total)                 : 11.92 words/cycle
#         Read Bandwidth (per-instance)            : 0.99 words/cycle
#         Read Bandwidth (total)                   : 3.96 words/cycle
#         Write Bandwidth (per-instance)           : 1.99 words/cycle
#         Write Bandwidth (total)                  : 7.96 words/cycle
#
# Level 2
# -------
# === input_activation_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 4
#         Utilized clusters (max)                  : 4
#         Scalar reads (per-instance)              : 7840000
#         Scalar fills (per-instance)              : 7840000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 15680000
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 2257920.00 pJ
#         Energy (total)                           : 9031680.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 8.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 4.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 4.00 words/cycle
#
# Level 3
# -------
# === weight_reg ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 1
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 1
#         Min utilization                 : 0.00
#         Vector access energy            : 0.14 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 35123.20 pJ
#         Area                            : 95.68 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 200
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 4
#         Utilized clusters (max)                  : 4
#         Scalar reads (per-instance)              : 7840000
#         Scalar fills (per-instance)              : 10000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 7850000
#         Energy (per-scalar-access)               : 0.14 pJ
#         Energy (per-instance)                    : 1130400.00 pJ
#         Energy (total)                           : 4521600.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 4.01 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 4.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#
# Level 4
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 128
#         Word bits                       : 16
#         Block size                      : 1
#         Cluster size                    : 1
#         Instances                       : 16 (1*16)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 128
#         Min utilization                 : 0.00
#         Vector access energy            : 0.83 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 24235.01 pJ
#         Area                            : 1965.98 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 200
#         Utilized capacity                        : 25
#         Utilized instances (max)                 : 4
#         Utilized clusters (max)                  : 4
#         Scalar reads (per-instance)              : 10000
#         Scalar fills (per-instance)              : 10000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 20000
#         Energy (per-scalar-access)               : 0.83 pJ
#         Energy (per-instance)                    : 16683.20 pJ
#         Energy (total)                           : 66732.80 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.00 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.01 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#
# Level 6
# -------
# === global_buffer ===
#
#     SPECS
#     -----
#         Technology                      : SRAM
#         Size                            : 16384
#         Word bits                       : 16
#         Block size                      : 8
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : 16384
#         Min utilization                 : 0.00
#         Vector access energy            : 27.53 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 7268.52 pJ
#         Area                            : 97538.70 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 100
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 40000
#         Scalar fills (per-instance)              : 40000
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 80000
#         Energy (per-scalar-access)               : 2.99 pJ
#         Energy (per-instance)                    : 239174.00 pJ
#         Energy (total)                           : 239174.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.01 words/cycle
#         Read Bandwidth (total)                   : 0.01 words/cycle
#         Write Bandwidth (per-instance)           : 0.01 words/cycle
#         Write Bandwidth (total)                  : 0.01 words/cycle
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 1024
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 7840000
#         Scalar fills (per-instance)              : 409600
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 8249600
#         Energy (per-scalar-access)               : 2.58 pJ
#         Energy (per-instance)                    : 21310654.88 pJ
#         Energy (total)                           : 21310654.88 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 1.05 words/cycle
#         Shared Bandwidth (total)                 : 1.05 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.05 words/cycle
#         Write Bandwidth (total)                  : 0.05 words/cycle
#     Outputs:
#         Partition size                           : 313600
#         Utilized capacity                        : 3136
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 31046400
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 31360000
#         Temporal reductions (per-instance)       : 31046400
#         Address generations (per-cluster)        : 31360000
#         Energy (per-scalar-access)               : 2.99 pJ
#         Energy (per-instance)                    : 186716365.92 pJ
#         Energy (total)                           : 186716365.92 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 7.96 words/cycle
#         Shared Bandwidth (total)                 : 7.96 words/cycle
#         Read Bandwidth (per-instance)            : 3.96 words/cycle
#         Read Bandwidth (total)                   : 3.96 words/cycle
#         Write Bandwidth (per-instance)           : 4.00 words/cycle
#         Write Bandwidth (total)                  : 4.00 words/cycle
#
# Level 7
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                      : DRAM
#         Size                            : -
#         Word bits                       : 16
#         Block size                      : 4
#         Cluster size                    : 1
#         Instances                       : 1 (1*1)
#         Shared bandwidth                : -
#         Read bandwidth                  : -
#         Write bandwidth                 : -
#         Multiple buffering              : 1.00
#         Effective size                  : -
#         Min utilization                 : 0.00
#         Vector access energy            : 512.00 pJ
#         Vector access energy source     : ERT
#         Per-instance-cycle leakage      : 0.00 pJ
#         Instances sharing power gating  : 1.00
#         Non-power-gated utilization     : 100.00%
#         Leakage energy (total)          : 0.00 pJ
#         Area                            : 0.00 um^2
#
#     STATS
#     -----
#     Cycles               : 7840000
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 800
#         Utilized capacity                        : 800
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 40000
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 40000
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 5120000.00 pJ
#         Energy (total)                           : 5120000.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.01 words/cycle
#         Shared Bandwidth (total)                 : 0.01 words/cycle
#         Read Bandwidth (per-instance)            : 0.01 words/cycle
#         Read Bandwidth (total)                   : 0.01 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Inputs:
#         Partition size                           : 204800
#         Utilized capacity                        : 204800
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 409600
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 409600
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 52428800.00 pJ
#         Energy (total)                           : 52428800.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.05 words/cycle
#         Shared Bandwidth (total)                 : 0.05 words/cycle
#         Read Bandwidth (per-instance)            : 0.05 words/cycle
#         Read Bandwidth (total)                   : 0.05 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 313600
#         Utilized capacity                        : 313600
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar fills (per-instance)              : 0
#         Scalar updates (per-instance)            : 313600
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 313600
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 40140800.00 pJ
#         Energy (total)                           : 40140800.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Bandwidth Consumption Scale              : 1.00
#         Shared Bandwidth (per-instance)          : 0.04 words/cycle
#         Shared Bandwidth (total)                 : 0.04 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.04 words/cycle
#         Write Bandwidth (total)                  : 0.04 words/cycle
#
# Networks
# --------
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 31360000
#     Total reduction ops                     : 31046400
#     Total ops                               : 62406400
#     Total memory accesses required          : 519200
#     Optimal Op per Byte                     : 60.10
#
# === output_activation_reg ===
#     Total scalar accesses                   : 93452800
#     Op per Byte                             : 0.33
# === input_activation_reg ===
#     Total scalar accesses                   : 62720000
#     Op per Byte                             : 0.50
# === weight_reg ===
#     Total scalar accesses                   : 31400000
#     Op per Byte                             : 0.99
# === scratchpad ===
#     Total scalar accesses                   : 80000
#     Op per Byte                             : 390.04
# === inter_PE_spatial ===
# === global_buffer ===
#     Total scalar accesses                   : 70736000
#     Op per Byte                             : 0.44
# === DRAM ===
#     Total scalar accesses                   : 763200
#     Op per Byte                             : 40.88
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 7.96
# Utilization: 25.00%
# Cycles: 7840000
# Energy: 435.87 uJ
# EDP(J*cycle): 3.42e+03
# Area: 0.00 mm^2
#
# Computes = 31360000
# fJ/Compute
#     mac                                             = 3275.00
#     output_activation_reg                           = 430.24
#     input_activation_reg                            = 289.12
#     weight_reg                                      = 145.30
#     scratchpad                                      = 2.90
#     global_buffer                                   = 6641.37
#     DRAM                                            = 3115.10
#     Total                                           = 13899.04

# %%
# Answer by setting these variables
four_pe_input_reads = 7840000 # YOUR ANSWER HERE
four_pe_weight_reads = 40000 # YOUR ANSWER HERE
four_pe_output_reads = 31046400 # YOUR ANSWER HERE
########################
#### YOUR CODE HERE ####
########################
answer(
    question='2.4',
    subquestion=f'How many input reads does each utilized PE fetch from the global_buffer now?',
    answer=four_pe_input_reads,
    required_type=Number
)
answer(
    question='2.4',
    subquestion=f'How many weight reads does each utilized PE fetch from the global_buffer now?',
    answer=four_pe_weight_reads,
    required_type=Number
)
answer(
    question='2.4',
	subquestion=f'How many output reads does each utilized PE fetch from the global_buffer now?',
	answer=four_pe_output_reads,
	required_type=Number
)

manual_four_pe_global_buffer_reads = four_pe_input_reads + four_pe_weight_reads + four_pe_output_reads

print('If you answered correctly, the following equality should hold.')
print(f'Is {manual_four_pe_global_buffer_reads} == {38926400.0}? {manual_four_pe_global_buffer_reads == 38926400.0}.')
# Out:
# 2.4: How many input reads does each utilized PE fetch from the global_buffer now?
# 	7840000
# 2.4: How many weight reads does each utilized PE fetch from the global_buffer now?
# 	40000
# 2.4: How many output reads does each utilized PE fetch from the global_buffer now?
# 	31046400
# If you answered correctly, the following equality should hold.
# Is 38926400 == 38926400.0? True.

# %% [markdown]
# As you can see, the number of input reads has decreased by

# %%
print(f'{one_pe_input_reads/four_pe_input_reads} times')
# Out:
# 4.0 times

# %% [markdown]
# Although since input reads are only a subset of total reads, the total reduction is only

# %%
print(f'{manual_one_pe_global_buffer_reads/manual_four_pe_global_buffer_reads} times')
# Out:
# 1.6042171893624892 times

# %% [markdown]
# This is because mapping the `M` rank spatially means that instead of reading the
# same input four times temporally, the input is read once from the global buffer
# and multicasted to the four PEs that will use it.
